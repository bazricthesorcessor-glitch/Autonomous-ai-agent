# %%
import torch
import transformers
print(torch.__version__)
print(torch.cuda.is_available())
print(transformers.__version__)
# Out:
# 2.10.0+cu128
# True
# 5.0.0

# %%
model_path = "/kaggle/input/models/google/gemma-4/transformers/gemma-4-26b-a4b-it/1"

tokenizer = AutoTokenizer.from_pretrained(model_path)

model = AutoModelForCausalLM.from_pretrained(
    model_path,
    torch_dtype=torch.bfloat16,
    device_map="auto"
)

print("Gemma loaded")
# Out:
# You are using a model of type gemma4 to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1383             try:
# -> 1384                 config_class = CONFIG_MAPPING[config_dict["model_type"]]
#    1385             except KeyError:
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/configuration_auto.py in __getitem__(self, key)
#    1086         if key not in self._mapping:
# -> 1087             raise KeyError(key)
#    1088         value = self._mapping[key]
#
# KeyError: 'gemma4'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_57/3494147550.py in <cell line: 0>()
#       3 tokenizer = AutoTokenizer.from_pretrained(model_path)
#       4
# ----> 5 model = AutoModelForCausalLM.from_pretrained(
#       6     model_path,
#       7     torch_dtype=torch.bfloat16,
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     315                 _ = kwargs.pop("quantization_config")
#     316
# --> 317             config, kwargs = AutoConfig.from_pretrained(
#     318                 pretrained_model_name_or_path,
#     319                 return_unused_kwargs=True,
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1384                 config_class = CONFIG_MAPPING[config_dict["model_type"]]
#    1385             except KeyError:
# -> 1386                 raise ValueError(
#    1387                     f"The checkpoint you are trying to load has model type `{config_dict['model_type']}` "
#    1388                     "but Transformers does not recognize this architecture. This could be because of an "
#
# ValueError: The checkpoint you are trying to load has model type `gemma4` but Transformers does not recognize this architecture. This could be because of an issue with the checkpoint, or because your version of Transformers is out of date.
#
# You can update Transformers with the command `pip install --upgrade transformers`. If this does not work, and the checkpoint is very new, then there may not be a release version that supports this model yet. In this case, you can get the most up-to-date code by installing Transformers from source with the command `pip install git+https://github.com/huggingface/transformers.git`

# %%
import gradio as gr

def chat(message):
    result = pipe(
        message,
        max_new_tokens=50
    )[0]["generated_text"]

    return result

demo = gr.Interface(
    fn=chat,
    inputs="text",
    outputs="text"
)

demo.launch(share=True)
