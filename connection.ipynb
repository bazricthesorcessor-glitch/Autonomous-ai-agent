# %%
import os
import shutil
import subprocess

# Install zstd only if missing
if shutil.which("zstd") is None:
    print("Installing zstd...")
    subprocess.run(
        "apt-get update -qq && apt-get install -y zstd",
        shell=True,
        check=True
    )
else:
    print("zstd already installed")

# Install ollama only if missing
if shutil.which("ollama") is None:
    print("Installing Ollama...")
    subprocess.run(
        "curl -fsSL https://ollama.com/install.sh | sh",
        shell=True,
        check=True
    )
else:
    print("Ollama already installed")

print("Setup complete")
# Out:
# Installing zstd...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   zstd
# 0 upgraded, 1 newly installed, 0 to remove and 218 not upgraded.
# Need to get 603 kB of archives.
# After this operation, 1,695 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Fetched 603 kB in 0s (5,864 kB/s)
# Selecting previously unselected package zstd.
# (Reading database ... 124626 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# ...

# %%
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# Out:
# --2026-05-08 11:16:23--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2026.3.0/cloudflared-linux-amd64 [following]
# --2026-05-08 11:16:23--  https://github.com/cloudflare/cloudflared/releases/download/2026.3.0/cloudflared-linux-amd64
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !chmod +x cloudflared

# %%
import subprocess

tunnel = subprocess.Popen(
    './cloudflared tunnel --url http://127.0.0.1:11434 --http-host-header "127.0.0.1:11434"',
    shell=True
)

print("Tunnel started")
# Out:
# Tunnel started

# %%
import os
import subprocess

os.environ["OLLAMA_HOST"] = "0.0.0.0:11434"

process = subprocess.Popen(
    "ollama serve",
    shell=True
)

print("Ollama restarted on 0.0.0.0")
# Out:
# Ollama restarted on 0.0.0.0

# %%
# !ollama list
# Out:
# Couldn't find '/root/.ollama/id_ed25519'. Generating new private key.
# Your new public key is:
#
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAILc7Rj08KFI0LAopT1IFvoQN1B+61YPPzNyJ7GYR47Tw
#
# ]11;?\
# ...

# %%
# !time ollama run gemma4:26b "give a number between 1 to 10"
# Out:
# ]11;?\
# 2026-05-08T11:16:30Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveP256] connIndex=0 event=0 ip=198.41.192.47
# 2026-05-08T11:16:30Z ERR failed to run the datagram handler error="context canceled" connIndex=0 event=0 ip=198.41.192.47
# 2026-05-08T11:16:30Z ERR failed to serve tunnel connection error="control stream encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.47
# 2026-05-08T11:16:30Z ERR Serve tunnel error error="control stream encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.47
# 2026-05-08T11:16:30Z INF Retrying connection in up to 4s connIndex=0 event=0 ip=198.41.192.47
# 2026-05-08T11:16:31Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveP256] connIndex=0 event=0 ip=198.41.192.47
# 2026-05-08T11:16:31Z ERR failed to run the datagram handler error="context canceled" connIndex=0 event=0 ip=198.41.192.47
# ...

# %%
# !pkill cloudflared
# Out:
# 2026-05-08T11:22:21Z INF Initiating graceful shutdown due to signal terminated ...
# 2026-05-08T11:22:21Z ERR failed to run the datagram handler error="Application error 0x0 (remote)" connIndex=0 event=0 ip=198.41.192.47
# 2026-05-08T11:22:21Z ERR failed to serve tunnel connection error="accept stream listener encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.47
# 2026-05-08T11:22:21Z ERR Serve tunnel error error="accept stream listener encountered a failure while serving" connIndex=0 event=0 ip=198.41.192.47
# 2026-05-08T11:22:21Z INF Retrying connection in up to 1s connIndex=0 event=0 ip=198.41.192.47
# 2026-05-08T11:22:21Z ERR Connection terminated connIndex=0
# 2026-05-08T11:22:21Z ERR no more connections active and exiting
# 2026-05-08T11:22:21Z INF Tunnel server stopped
# 2026-05-08T11:22:21Z INF Metrics server stopped
